# %% [markdown]
# # 1. 불필요한 컬럼 삭제

# %%
import pandas as pd

# %%
data = pd.read_csv('../../../data/titanic.csv')

# %%
data[data.duplicated()]
# Out:
#      Pclass                           Name   Gendr   Age  SibSp  Parch  \
# 25        3  Palsson, Miss. Torborg Danira  female   8.0      3      1
# 632       3             Skoog, Miss. Mabel  female   9.0      3      2
# 714       1  Endres, Miss. Caroline Louise  female  38.0      0      0
#
#        Ticket Embarked  Survived ticket_date
# 25     349909        S         0  1912-03-14
# 632    347088        S         0  1912-03-16
# 714  PC 17757        C         1  1912-03-14

# %%
data.drop_duplicates()
# Out:
#      Pclass                                               Name   Gendr   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 880       2                              Montvila, Rev. Juozas    male  27.0
# 881       1                       Graham, Miss. Margaret Edith  female  19.0
# 882       3           Johnston, Miss. Catherine Helen "Carrie"  female  28.0
# 883       1                              Behr, Mr. Karl Howell    male  26.0
# 884       3                                Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch            Ticket Embarked  Survived ticket_date
# 0        1      0         A/5 21171        S         0  1912-01-12
# 1        1      0          PC 17599        C         1  1912-03-29
# 2        0      0  STON/O2. 3101282        S         1  1912-02-23
# 3        1      0            113803        S         1  1912-03-28
# 4        0      0            373450        S         0  1912-04-03
# ..     ...    ...               ...      ...       ...         ...
# 880      0      0            211536        S         0  1912-01-29
# 881      0      0            112053        S         1  1912-03-30
# 882      1      2        W./C. 6607        S         0  1912-04-07
# 883      0      0            111369        C         1  1912-03-01
# 884      0      0            370376        Q         0  1912-03-05
#
# [882 rows x 10 columns]

# %%
data.head()
# Out:
#    Pclass                                               Name   Gendr   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket Embarked  Survived ticket_date
# 0      1      0         A/5 21171        S         0  1912-01-12
# 1      1      0          PC 17599        C         1  1912-03-29
# 2      0      0  STON/O2. 3101282        S         1  1912-02-23
# 3      1      0            113803        S         1  1912-03-28
# 4      0      0            373450        S         0  1912-04-03

# %%
data.drop('Name', axis = 1)
# Out:
#      Pclass   Gendr   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0         3    male  22.0      1      0         A/5 21171        S         0
# 1         1  female  38.0      1      0          PC 17599        C         1
# 2         3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3         1  female   NaN      1      0            113803        S         1
# 4         3    male  35.0      0      0            373450        S         0
# ..      ...     ...   ...    ...    ...               ...      ...       ...
# 880       2    male  27.0      0      0            211536        S         0
# 881       1  female  19.0      0      0            112053        S         1
# 882       3  female  28.0      1      2        W./C. 6607        S         0
# 883       1    male  26.0      0      0            111369        C         1
# 884       3    male  32.0      0      0            370376        Q         0
#
#     ticket_date
# 0    1912-01-12
# 1    1912-03-29
# 2    1912-02-23
# 3    1912-03-28
# 4    1912-04-03
# ..          ...
# 880  1912-01-29
# 881  1912-03-30
# 882  1912-04-07
# 883  1912-03-01
# 884  1912-03-05
#
# [885 rows x 9 columns]

# %%
data.drop(['Pclass','Age'], axis = 1)
# Out:
#                                                   Name   Gendr  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ..                                                 ...     ...    ...    ...
# 880                              Montvila, Rev. Juozas    male      0      0
# 881                       Graham, Miss. Margaret Edith  female      0      0
# 882           Johnston, Miss. Catherine Helen "Carrie"  female      1      2
# 883                              Behr, Mr. Karl Howell    male      0      0
# 884                                Dooley, Mr. Patrick    male      0      0
#
#                Ticket Embarked  Survived ticket_date
# 0           A/5 21171        S         0  1912-01-12
# 1            PC 17599        C         1  1912-03-29
# 2    STON/O2. 3101282        S         1  1912-02-23
# 3              113803        S         1  1912-03-28
# 4              373450        S         0  1912-04-03
# ..                ...      ...       ...         ...
# 880            211536        S         0  1912-01-29
# 881            112053        S         1  1912-03-30
# 882        W./C. 6607        S         0  1912-04-07
# 883            111369        C         1  1912-03-01
# 884            370376        Q         0  1912-03-05
#
# [885 rows x 8 columns]

# %%
data.head()
# Out:
#    Pclass                                               Name   Gendr   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket Embarked  Survived ticket_date
# 0      1      0         A/5 21171        S         0  1912-01-12
# 1      1      0          PC 17599        C         1  1912-03-29
# 2      0      0  STON/O2. 3101282        S         1  1912-02-23
# 3      1      0            113803        S         1  1912-03-28
# 4      0      0            373450        S         0  1912-04-03

# %%
data.drop(['Name','Age','Pclass'], axis = 1, inplace = True)

# %%
data.head()
# Out:
#     Gendr  SibSp  Parch            Ticket Embarked  Survived ticket_date
# 0    male      1      0         A/5 21171        S         0  1912-01-12
# 1  female      1      0          PC 17599        C         1  1912-03-29
# 2  female      0      0  STON/O2. 3101282        S         1  1912-02-23
# 3  female      1      0            113803        S         1  1912-03-28
# 4    male      0      0            373450        S         0  1912-04-03

# %%
data.loc[[4,5,6]]
# Out:
#   Gendr  SibSp  Parch  Ticket Embarked  Survived ticket_date
# 4  male      0      0  373450        S         0  1912-04-03
# 5  male      0      0  330877        Q         0  1912-03-30
# 6  male      0      0   17463        S         0  1912-03-14

# %%
data.loc[4:]
# Out:
#       Gendr  SibSp  Parch      Ticket Embarked  Survived ticket_date
# 4      male      0      0      373450        S         0  1912-04-03
# 5      male      0      0      330877        Q         0  1912-03-30
# 6      male      0      0       17463        S         0  1912-03-14
# 7      male      3      1      349909        S         0  1912-03-14
# 8    female      0      2      347742        S         1  1912-01-30
# ..      ...    ...    ...         ...      ...       ...         ...
# 880    male      0      0      211536        S         0  1912-01-29
# 881  female      0      0      112053        S         1  1912-03-30
# 882  female      1      2  W./C. 6607        S         0  1912-04-07
# 883    male      0      0      111369        C         1  1912-03-01
# 884    male      0      0      370376        Q         0  1912-03-05
#
# [881 rows x 7 columns]

# %%
data.iloc[[4,5,6]]
# Out:
#   Gendr  SibSp  Parch  Ticket Embarked  Survived ticket_date
# 4  male      0      0  373450        S         0  1912-04-03
# 5  male      0      0  330877        Q         0  1912-03-30
# 6  male      0      0   17463        S         0  1912-03-14

# %%
data.isna().sum()
# Out:
# Gendr          0
# SibSp          0
# Parch          0
# Ticket         0
# Embarked       2
# Survived       0
# ticket_date    0
# dtype: int64

# %%
data.isna().mean()
# Out:
# Gendr          0.00000
# SibSp          0.00000
# Parch          0.00000
# Ticket         0.00000
# Embarked       0.00226
# Survived       0.00000
# ticket_date    0.00000
# dtype: float64

# %%
embarked_na_index = data[data['Embarked'].isna()].index

# %%
embarked_na_index
# Out:
# Int64Index([15, 322], dtype='int64')

# %%
data.loc[embarked_na_index]
# Out:
#       Gendr  SibSp  Parch    Ticket Embarked  Survived ticket_date
# 15   female      0      0    248706      NaN         1  1912-03-05
# 322    male      8      2  CA. 2343      NaN         0  1912-03-26

# %%
data = pd.read_csv('../../../data/titanic.csv')

# %%
data.head()
# Out:
#    Pclass                                               Name   Gendr   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket Embarked  Survived ticket_date
# 0      1      0         A/5 21171        S         0  1912-01-12
# 1      1      0          PC 17599        C         1  1912-03-29
# 2      0      0  STON/O2. 3101282        S         1  1912-02-23
# 3      1      0            113803        S         1  1912-03-28
# 4      0      0            373450        S         0  1912-04-03

# %%
data.drop('Name', axis = 1, inplace = True)

# %%
data.head()
# Out:
#    Pclass   Gendr   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0       3    male  22.0      1      0         A/5 21171        S         0
# 1       1  female  38.0      1      0          PC 17599        C         1
# 2       3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3       1  female   NaN      1      0            113803        S         1
# 4       3    male  35.0      0      0            373450        S         0
#
#   ticket_date
# 0  1912-01-12
# 1  1912-03-29
# 2  1912-02-23
# 3  1912-03-28
# 4  1912-04-03

# %%
len(data)
# Out:
# 885

# %%
data.dropna()
# Out:
#      Pclass   Gendr   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0         3    male  22.0      1      0         A/5 21171        S         0
# 1         1  female  38.0      1      0          PC 17599        C         1
# 2         3  female  26.0      0      0  STON/O2. 3101282        S         1
# 4         3    male  35.0      0      0            373450        S         0
# 5         3    male  28.0      0      0            330877        Q         0
# ..      ...     ...   ...    ...    ...               ...      ...       ...
# 880       2    male  27.0      0      0            211536        S         0
# 881       1  female  19.0      0      0            112053        S         1
# 882       3  female  28.0      1      2        W./C. 6607        S         0
# 883       1    male  26.0      0      0            111369        C         1
# 884       3    male  32.0      0      0            370376        Q         0
#
#     ticket_date
# 0    1912-01-12
# 1    1912-03-29
# 2    1912-02-23
# 4    1912-04-03
# 5    1912-03-30
# ..          ...
# 880  1912-01-29
# 881  1912-03-30
# 882  1912-04-07
# 883  1912-03-01
# 884  1912-03-05
#
# [877 rows x 9 columns]

# %%
len(data)
# Out:
# 885

# %%
data['Age'] = data['Age'].fillna(data['Age'].median())

# %%
age_na_index = data['Age'].isna().index

# %%
age_na_index
# Out:
# RangeIndex(start=0, stop=885, step=1)

# %%
data.loc[age_na_index]
# Out:
#      Pclass   Gendr   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0         3    male  22.0      1      0         A/5 21171        S         0
# 1         1  female  38.0      1      0          PC 17599        C         1
# 2         3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3         1  female  28.0      1      0            113803        S         1
# 4         3    male  35.0      0      0            373450        S         0
# ..      ...     ...   ...    ...    ...               ...      ...       ...
# 880       2    male  27.0      0      0            211536        S         0
# 881       1  female  19.0      0      0            112053        S         1
# 882       3  female  28.0      1      2        W./C. 6607        S         0
# 883       1    male  26.0      0      0            111369        C         1
# 884       3    male  32.0      0      0            370376        Q         0
#
#     ticket_date
# 0    1912-01-12
# 1    1912-03-29
# 2    1912-02-23
# 3    1912-03-28
# 4    1912-04-03
# ..          ...
# 880  1912-01-29
# 881  1912-03-30
# 882  1912-04-07
# 883  1912-03-01
# 884  1912-03-05
#
# [885 rows x 9 columns]

# %%
embarked_na_index = data[data['Embarked'].isna()].index

# %%
age_na_index = data[data['Age'].isna()].index

# %%
data.loc[age_na_index]
# Out:
# Empty DataFrame
# Columns: [Pclass, Gendr, Age, SibSp, Parch, Ticket, Embarked, Survived, ticket_date]
# Index: []

# %%
data['Embarked'].value_counts()
# Out:
# S    640
# C    166
# Q     77
# Name: Embarked, dtype: int64

# %%
data['Age'].sort_values()
# Out:
# 163      1.0
# 823      1.0
# 379      1.0
# 384      1.0
# 785      1.0
#        ...
# 490     71.0
# 845     74.0
# 627     80.0
# 279     97.0
# 321    145.0
# Name: Age, Length: 885, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot(data['SibSp'])

# %%
sns.displot(data['Age'])

# %%
sns.scatterplot(x= data.index, y = data['Age'])
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.scatterplot(x = data.index, y = data['SibSp'])
# Out:
# <AxesSubplot:ylabel='SibSp'>

# %%
sns.boxplot(data['Age'])
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
def age_func(x):
    if x > 80:
        return 80
    else:
        return x

# %%
data['Age'].apply(age_func).max()
# Out:
# 80.0

# %%
def new_age_func(x):
    if x > 70:
        return 80
    else:
        return x

# %%
data['Age'].apply(lambda x: 70 if x > 70 else x)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      28.0
# 4      35.0
#        ...
# 880    27.0
# 881    19.0
# 882    28.0
# 883    26.0
# 884    32.0
# Name: Age, Length: 885, dtype: float64

# %%
data['Age'].sort_values()
# Out:
# 163      1.0
# 823      1.0
# 379      1.0
# 384      1.0
# 785      1.0
#        ...
# 490     71.0
# 845     74.0
# 627     80.0
# 279     97.0
# 321    145.0
# Name: Age, Length: 885, dtype: float64

# %%
data = data.rename({'Gendr' : 'Gender'}, axis = 1)

# %%
data.replace({'S': 'Southhampton', 'C': 'Cherbourg', 'Q': 'Queenstown'})
# Out:
#      Pclass  Gender   Age  SibSp  Parch            Ticket      Embarked  \
# 0         3    male  22.0      1      0         A/5 21171  Southhampton
# 1         1  female  38.0      1      0          PC 17599     Cherbourg
# 2         3  female  26.0      0      0  STON/O2. 3101282  Southhampton
# 3         1  female  28.0      1      0            113803  Southhampton
# 4         3    male  35.0      0      0            373450  Southhampton
# ..      ...     ...   ...    ...    ...               ...           ...
# 880       2    male  27.0      0      0            211536  Southhampton
# 881       1  female  19.0      0      0            112053  Southhampton
# 882       3  female  28.0      1      2        W./C. 6607  Southhampton
# 883       1    male  26.0      0      0            111369     Cherbourg
# 884       3    male  32.0      0      0            370376    Queenstown
#
#      Survived ticket_date
# 0           0  1912-01-12
# 1           1  1912-03-29
# 2           1  1912-02-23
# 3           1  1912-03-28
# 4           0  1912-04-03
# ..        ...         ...
# 880         0  1912-01-29
# 881         1  1912-03-30
# 882         0  1912-04-07
# 883         1  1912-03-01
# 884         0  1912-03-05
#
# [885 rows x 9 columns]

# %%
data['new_ticket'] = data['Ticket'].str.split().apply(lambda x: x[-1])

# %%
data
# Out:
#      Pclass  Gender   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0         3    male  22.0      1      0         A/5 21171        S         0
# 1         1  female  38.0      1      0          PC 17599        C         1
# 2         3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3         1  female  28.0      1      0            113803        S         1
# 4         3    male  35.0      0      0            373450        S         0
# ..      ...     ...   ...    ...    ...               ...      ...       ...
# 880       2    male  27.0      0      0            211536        S         0
# 881       1  female  19.0      0      0            112053        S         1
# 882       3  female  28.0      1      2        W./C. 6607        S         0
# 883       1    male  26.0      0      0            111369        C         1
# 884       3    male  32.0      0      0            370376        Q         0
#
#     ticket_date new_ticket
# 0    1912-01-12      21171
# 1    1912-03-29      17599
# 2    1912-02-23    3101282
# 3    1912-03-28     113803
# 4    1912-04-03     373450
# ..          ...        ...
# 880  1912-01-29     211536
# 881  1912-03-30     112053
# 882  1912-04-07       6607
# 883  1912-03-01     111369
# 884  1912-03-05     370376
#
# [885 rows x 10 columns]

# %%
data[~data['new_ticket'].str.isdigit()]
# Out:
#      Pclass Gender   Age  SibSp  Parch Ticket Embarked  Survived ticket_date  \
# 178       3   male  36.0      0      0   LINE        S         0  1912-04-08
# 270       3   male  25.0      0      0   LINE        S         1  1912-04-08
# 301       3   male  19.0      0      0   LINE        S         0  1912-04-08
# 594       3   male  49.0      0      0   LINE        S         0  1912-04-08
#
#     new_ticket
# 178       LINE
# 270       LINE
# 301       LINE
# 594       LINE

# %%
data['new_ticket'] = data['new_ticket'].replace({'LINE' : '999999'})

# %%
data['new_ticket'].astype('int')
# Out:
# 0        21171
# 1        17599
# 2      3101282
# 3       113803
# 4       373450
#         ...
# 880     211536
# 881     112053
# 882       6607
# 883     111369
# 884     370376
# Name: new_ticket, Length: 885, dtype: int64

# %%
from datetime import datetime

# %%
data['ticket_date'] = pd.to_datetime(data['ticket_date'])

# %%
data['ticket_date'].dt.month
# Out:
# 0      1
# 1      3
# 2      2
# 3      3
# 4      4
#       ..
# 880    1
# 881    3
# 882    4
# 883    3
# 884    3
# Name: ticket_date, Length: 885, dtype: int64

# %%
 acc = datetime.strptime('1912-04-15', '%Y-%m-%d')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885 entries, 0 to 884
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pclass       885 non-null    int64
#  1   Gender       885 non-null    object
#  2   Age          885 non-null    float64
#  3   SibSp        885 non-null    int64
#  4   Parch        885 non-null    int64
#  5   Ticket       885 non-null    object
#  6   Embarked     883 non-null    object
#  7   Survived     885 non-null    int64
#  8   ticket_date  885 non-null    datetime64[ns]
#  9   new_ticket   885 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(4)
# memory usage: 69.3+ KB

# %%
data['buy_before'] = acc - data['ticket_date']

# %%
data['buy_before'] = data['buy_before'].dt.days

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885 entries, 0 to 884
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pclass       885 non-null    int64
#  1   Gender       885 non-null    object
#  2   Age          885 non-null    float64
#  3   SibSp        885 non-null    int64
#  4   Parch        885 non-null    int64
#  5   Ticket       885 non-null    object
#  6   Embarked     883 non-null    object
#  7   Survived     885 non-null    int64
#  8   ticket_date  885 non-null    datetime64[ns]
#  9   new_ticket   885 non-null    object
#  10  buy_before   885 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(4)
# memory usage: 76.2+ KB
